# %% [markdown]
# ### import data using Pandas

# %%
import pandas as pd

# %%
fname = '/data/pubmed-data.tsv'
df = pd.read_csv(fname, sep='\t')
df
# Out:
#                                                  search_id  \
# 0        --0im32mfvku4cesslp_7q:bcdf32b416db8defc59a9e5...
# 1        --0pulmnb15g9zqvin3qew:a36687cca419d408a8fc07b...
# 2        --beh2-embzwxbaldmvo-w:fd7e447a7b102cf1ec1c31b...
# 3        --ez48ba9jyoxpzcgxpvmq:342fa0883e0991845d7197d...
# 4        --gijgarezrbtkdhr0jdng:1955381aef88ba6bd5c5478...
# ...                                                    ...
# 1309445  zzzqz7knyd9jdt9-2_g0da:9c638e1f56a958f6944de1b...
# 1309446  zzzs93p3aldxufvao0vqeq:351b02db7e607c1bb35ea69...
# 1309447  zzztisyizwd8hdoosvivwa:e42c86f4236e54427f287d8...
# 1309448  zzzxqxmj8gzbqvettqq6na:83b3d7606fb8a568aeb5eff...
# 1309449  zzzydin-inx3ttzxgbe0wa:a63a58616965396f2024f9e...
#
#                                                 query_term  \
# 0                                          pollen allergen
# 1                        sacubitril valsartan and xiabetic
# 2                                                 organoid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309450 entries, 0 to 1309449
# Data columns (total 12 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   search_id        1309450 non-null  object
#  1   query_term       1309128 non-null  object
#  2   filters          1309450 non-null  object
#  3   sort_algorithm   1309450 non-null  object
#  4   result_count     1309450 non-null  int64
#  5   page_num         1309450 non-null  int64
#  6   PMID             1309450 non-null  object
#  7   click_data       1309450 non-null  object
#  8   date             1309450 non-null  object
#  9   user_id          1309450 non-null  object
#  10  filters_active   1309450 non-null  bool
#  11  processed_query  1309188 non-null  object
# dtypes: bool(1), int64(2), object(9)
# memory usage: 111.1+ MB

# %%
df.sample(1000)
# Out:
#                                                 search_id  \
# 840015  3mwqv28hknk9jddtchexka:201c4c0224989c876f31504...
# 803007  tovf4i-iopfnssgb3nqrwg:bc2e45c63cc705824399fb2...
# 201676  oo0rdu85xruh_i8sdsycqg:6ee8492e7c4b59db6058e62...
# 626431  ep187evhbhhqskghxkzdtw:04cc23e4dca1e4ead99b6e8...
# 946888  lqcjljg8eejmu1hsw2c58g:46018f62321aed2feb5675a...
# ...                                                   ...
# 431818  1xrcecbpweelsujt69brcg:bf6b4172f5c17924d35f0e2...
# 137530  awho0nv9nbsnm_mqzuxjrw:507e8cd773709eeb3a04291...
# 142373  byb1olw1jdb2qlmv4gkiqw:b5cae686e9bdb4a291fadeb...
# 512524  lze1_pqhnh2k3aqzzptkgg:11e95bbf75858a298267035...
# 621583  dknxgyt5of0rpaqindpqia:46b1a3db43992a41f568e7d...
#
#                                                query_term filters  \
# 840015  treatment of patients with major depressive di...    None
# 803007                          surgery pain readmissions    None
# 201676  (resistance training[title/abstract]) and (car...    None
# ...
